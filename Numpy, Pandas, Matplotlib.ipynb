# %% [markdown]
# ## Numpy
# np.array(list)
# np.arange(0,10) From 0-10
# np.arange(0,11,2) - From 0-10 with diff of 2
# np.zeros(3) - 1D 3 element zeros array
# np.ones((3,3)) - 3 * 3 array with 1s
# np.linspace(0,10,3) - linear space
# np.eye(4) - identical 4 * 4
#
# np.random.rand(2)
# np.random.rand(5,5)
#
# arr = np.arange(25)
# arr.reshape(5,5)
#
# ranarr.max() - max value
# ranarr.argmax() - position of max value
#
# arr = np.arange(1,11)
# bool_arr = arr>4
# bool_arr - will display T or F values
# arr[bool_arr] - gives values that meet condition

# %% [markdown]
# ## Pandas
# pd.Series(list) - 1 dimentional labelled array - Series
# df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split()) - 2 dimensional labelled array - Dataframe
#
#
# #### Operations possible
# df['W']
#
# df[['W','Z']]
#
# df['new'] = df['W'] + df['Y']
#
# df.drop('new',axis=1) - to drop column new
#
# df[df>0] - to display values more than 0
#
# df[df['W']>0]
#
# df[df['W']>0]['Y'] - displays Y column where W column is > 0
#
#
# df.dropna() - to drop missing values
#
# df.dropna(axis=1) - to drop missing values (along column)
#
# df['A'].fillna(value=df['A'].mean()) - fill missing values with mean of rest of values
#
#
# df['col2'].unique() - to list unique values in col2
#
# df['col2'].nunique() - to list number of unique values in col2
#
#
# def times2(x):
#     return x*2
#
# df['col2'].apply(times2) - does 2 * each value in column col2
#
# df = pd.read_csv(File name) - to read csv file into a dataframe

# %% [markdown]
# ## Matplotlib
# plt.plot(x, y, 'r') # 'r' is the color red
#
# plt.xlabel('X Axis Title Here')
#
# plt.ylabel('Y Axis Title Here')
#
# plt.title('String Title Here')
#
#
# #### Subplots
# ##### plt.subplot(nrows, ncols, plot_number)
#
# plt.subplot(1,2,1)
#
# plt.plot(x, y, 'r--') # More on color options later
#
# plt.subplot(1,2,2)
#
# plt.plot(y, x, 'g*-')
#
# #### Creating figure
# ##### Create Figure (empty canvas)
# fig = plt.figure()
#
# ##### Add set of axes to figure
# axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)
#
# ##### Plot on that set of axes
# axes.plot(x, y, 'b')
#
# axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
#
# axes.set_ylabel('Set y Label')
#
# axes.set_title('Set Title')
#
# ##### Use similar to plt.figure() except use tuple unpacking to grab fig and axes
# fig, axes = plt.subplots()
#
# ##### Now use the axes object to add stuff to plot
# axes.plot(x, y, 'r')
#
# axes.set_xlabel('x')
#
# axes.set_ylabel('y')
#
# axes.set_title('title')
#
# axes
#
# ##### Another method
# fig, axes = plt.subplots(nrows=1, ncols=2)
#
# axes[0].plot(x, y, 'r')
#
# axes[1].plot(y, x, 'g')
#
# fig = plt.figure()
#
# ##### For legend
# ax = fig.add_axes([0,0,1,1])
#
# ax.plot(x, x**2, label="x**2")
#
# ax.plot(x, x**3, label="x**3")
#
# ax.legend()
#
# ##### Different patterns of lines
#
# fig, ax = plt.subplots(figsize=(12,6))
#
# ax.plot(x, x+1, color="red", linewidth=0.25)
#
# ax.plot(x, x+2, color="red", linewidth=0.50)
#
# ax.plot(x, x+3, color="red", linewidth=1.00)
#
# ax.plot(x, x+4, color="red", linewidth=2.00)
#
# ###### possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
# ax.plot(x, x+5, color="green", lw=3, linestyle='-')
#
# ax.plot(x, x+6, color="green", lw=3, ls='-.')
#
# ax.plot(x, x+7, color="green", lw=3, ls=':')
#
#
# ###### possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
# ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
#
# ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
#
# ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
#
# ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')
#
# ###### marker size and color
# ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
#
# ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
#
# ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
#
# ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8,
